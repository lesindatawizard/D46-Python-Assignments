# %%
# Exercise 1: Write a Python program to read a file and display its contents Exercise

# %%
file = open('End is near.txt','w')
file.write("Live happily, the end is near. You will only hear this message once. The end is near\n and it is coming near one at a time.")
file.close()

# %%
with open('End is near.txt','r') as death:
    content = death.read()
    print(content)
# Out:
# Live happily, the end is near. You will only hear this message once. The end is near
#  and it is coming near one at a time.

# %%
# Exercise 2: Write a Python program to copy the contents of one file to another file Exercise.

# %%
file_2 = open('escape.txt','w')
file_2.write("The only way to escape is face the end with a smile.")
file_2.close()

# %%
with open('escape.txt','r') as life:
    content_2 = life.read()
    print(content_2)
# Out:
# The only way to escape is face the end with a smile.

# %%
with open('escape.txt','r') as life, open('End is near.txt','w') as death:
    death.write(life.read())

# %%
with open('escape.txt','r') as life:
    content_2 = life.read()
    print(content_2)
# Out:
# Live happily, the end is near. You will only hear this message once. The end is near
#  and it is coming near one at a time.

# %%
# Exercise 3: Write a Python program to read the content of a file and count the total number of words in that file.

# %%
file_3 = open('profile.txt','w')
file_3.write("My name is Lesin Fargan Necholi and I am studying Data Science and Machine Learning")
file_3.close()

# %%
with open('profile.txt','r') as myself:
    content_3 = myself.read()
    print(content_3)
# Out:
# My name is Lesin Fargan Necholi and I am studying Data Science and Machine Learning

# %%
with open('profile.txt','r') as myself:
    content_3 = myself.read()
    length = len(content_3)
    print('The total number of words in profile.txt is:',length)
# Out:
# The total number of words in profile.txt is: 83

# %%
# Exercise 4: Write a Python program that prompts the user to input a string and converts it to an integer. Use try-except blocks to handle any exceptions that might occur

# %%
user_input = input("Enter the number to convert")
try:
    number = int(user_input)
    print(f"The integer is: {number}")
except ValueError:
    print("Error: The input is not a valid integer.")
# Out:
# Enter the number to convert 456
# The integer is: 456

# %%
# Exercise 5: Write a Python program that prompts the user to input a list of integers and raises an exception if any of the integers in the list are negative.

# %%
try:
    numbers = list(map(int, input("Enter integers separated by spaces: ").split()))
    for num in numbers:
        if num < 0:
            raise ValueError("Negative number found!")
    print("All numbers are non-negative.")
except ValueError as e:
    print("Error:", e)
# Out:
# Enter integers separated by spaces:  2 5 2 7 4 -1
# Error: Negative number found!

# %%
# Exercise 6: Write a Python program that prompts the user to input a list of integers and computes the average of those integers. Use try-except blocks to handle any exceptions that might occur.use the finally clause to print a message indicating that the program has finished running.

# %%
try:
    # Get user input
    numbers = list(map(int, input("Enter integers separated by spaces: ").split()))
    if len(numbers) == 0:
        raise ZeroDivisionError("Cannot compute average of an empty list.")
    # Calculate average
    average = sum(numbers) / len(numbers)
    print(f"The average is: {average}")
except ValueError:
    print("Error: Please enter only valid integers.")
except ZeroDivisionError as e:
    print("Error:", e)
except Exception as e:
    print("An unexpected error occurred:", e)
finally:
    print("Program has finished running.")
# Out:
# Enter integers separated by spaces:  5 3 7 4
# The average is: 4.75
# Program has finished running.

# %%
# Exercise 7 : Write a Python program that prompts the user to input a filename and writes a string to that file. Use try-except blocks to handle any exceptions that might occur and print a welcome message if there is no exception occurred.

# %%
try:
    filename = input("Enter the filename to write to: ")
    with open(filename, "w") as file:
        file.write("Hello! Welcome to the file.\nThis is a sample content.")
except Exception as e:
    print("An error occurred while writing to the file:", e)
else:
    print("Welcome! The file has been written successfully.")
# Out:
# Enter the filename to write to:  hi
# Welcome! The file has been written successfully.
